# %% [markdown]
# # Day Objectives:
#
# ## Pandas
# * Which is a buildin Library and using Pandas heavily for data manipulation, visualisation, building machine learning models, etc.
# * There are two main data structures in Pandas - Series and Dataframes
#
# ### The pandas Series (similar to a numpy array)
#
# * A dataframe is simply a table where each column is a pandas series.
#     * Creating a pandas series
#     * Indexing series
#
# ### Dataframes
#
# * Dataframe is the most widely used data-structure in data analysis. It is a table with rows and columns, with rows having an index and columns having meaningful names.
#
#
#
# [Pandas_cheat_sheet](http://datacamp-community-prod.s3.amazonaws.com/dbed353d-2757-4617-8206-8767ab379ab3)
#
#
# ### Data Analysis with Pandas
# - check the version
#
#     * Creating dataframes from dictionaries
#     * File I/O - Importing CSV data files as pandas dataframes
#     [Student_Details](https://raw.githubusercontent.com/AP-Skill-Development-Corporation/Swarnandhra_python/main/Day9_(Pandas%2CMatplotLib%2COops)/Students%20(5).csv)
#     * Reading and summarising dataframes
#     * Sorting dataframes
#     * Indexing
#         - Iloc & Loc
#     * Filtering
#     * Grouping
#     [Birds_dataset](https://drive.google.com/file/d/1A5Z-uNxmKLljstrX8j-1j2ydThYbe6JU/view?usp=sharing)
#     * Statistical
#     * Checking null values
#     * Saving
#
# id |col1 | col2
# --|--|--
# 1|678|xyz
# 2|123|sdf
# 3|454|jhg

# %%
import pandas as pd
# creating DF using Dict
di = {
    "Name" : pd.Series(["Tulasi","Pujitha","Manikanta","nikhil"],index=[1,2,3,4]),
    "Branch" : pd.Series(["cse","ec","Mech"],index=[1,2,4]),
    "DOB" : pd.Series([1990,2007,2008],index = [1,3,4])
}
df2 = pd.DataFrame(di)
df2
# NAN - Not a number - its special type float char
# Out:
#         Name Branch     DOB
# 1     Tulasi    cse  1990.0
# 2    Pujitha     ec     NaN
# 3  Manikanta    NaN  2007.0
# 4     nikhil   Mech  2008.0

# %%
# check the version
pd.__version__
# Out:
# '1.0.5'

# %%
# File I/O  - importing required files like CSV,excel, txt...
data = pd.read_csv("https://raw.githubusercontent.com/AP-Skill-Development-Corporation/Swarnandhra_python/main/Day9_(Pandas%2CMatplotLib%2COops)/Students%20(5).csv")
data
# Out:
#     S.No. Registration Id                         Name  \
# 0       1      12A21A0378           Peddakota Saikumar
# 1       2      18A21A0403              Adapa Nagarjuna
# 2       3      18A21A0405  Addala Mohan Sree Manikanta
# 3       4      18A21A0411     Andey Venkata Sai Ganesh
# 4       5      18A21A0412               Geetha Andraju
# ..    ...             ...                          ...
# 88     89      19A25B0408                  M Ravi Teja
# 89     90      19A25B0409       Nalluri  Pavan Chandra
# 90     91      19A25B0410                 P Sai Naveen
# 91     92      19A25B0411             Pulaparthi Pavan
# 92     93      19A25B0412          Sivanadh Vardhinedi
#
#                               Email   Mobile No
# 0           sai.peddakota@gmail.com  8142539492
# 1       nagarjunaadapa333@gmail.com  8897693199
# 2      manikantaaddala970@gmail.com  9704131588
# 3      andeysaiganesh1141@gmail.com  7730037728
# 4         geethaandraju88@gmail.com  9346857667
# ...

# %%
data.shape # 93 records
# Out:
# (93, 5)

# %%
data = pd.read_excel("")
data = pd.read_html("")

# %%
# Reading and summarising dataframes
data.head() # default it takes 5
# Out:
#    S.No. Registration Id                         Name  \
# 0      1      12A21A0378           Peddakota Saikumar
# 1      2      18A21A0403              Adapa Nagarjuna
# 2      3      18A21A0405  Addala Mohan Sree Manikanta
# 3      4      18A21A0411     Andey Venkata Sai Ganesh
# 4      5      18A21A0412               Geetha Andraju
#
#                           Email   Mobile No
# 0       sai.peddakota@gmail.com  8142539492
# 1   nagarjunaadapa333@gmail.com  8897693199
# 2  manikantaaddala970@gmail.com  9704131588
# 3  andeysaiganesh1141@gmail.com  7730037728
# 4     geethaandraju88@gmail.com  9346857667

# %%
data.tail(5)
# Out:
#     S.No. Registration Id                    Name  \
# 88     89      19A25B0408             M Ravi Teja
# 89     90      19A25B0409  Nalluri  Pavan Chandra
# 90     91      19A25B0410            P Sai Naveen
# 91     92      19A25B0411        Pulaparthi Pavan
# 92     93      19A25B0412     Sivanadh Vardhinedi
#
#                               Email   Mobile No
# 88     mathalaraviteja033@gmail.com  9603795633
# 89  pavanchowdarynalluri7@gmail.com  8977542433
# 90         naveensai88178@gmail.com  9550069937
# 91     pavanpulaparthi939@gmail.com  7893195069
# 92      sivavardhinedi335@gmail.com  9347086889

# %%
data.sample() # random
# Out:
#     S.No. Registration Id         Name                         Email  \
# 88     89      19A25B0408  M Ravi Teja  mathalaraviteja033@gmail.com
#
#      Mobile No
# 88  9603795633

# %%
data["Name"]
# Out:
# 0              Peddakota Saikumar
# 1                 Adapa Nagarjuna
# 2     Addala Mohan Sree Manikanta
# 3        Andey Venkata Sai Ganesh
# 4                  Geetha Andraju
#                  ...
# 88                    M Ravi Teja
# 89         Nalluri  Pavan Chandra
# 90                   P Sai Naveen
# 91               Pulaparthi Pavan
# 92            Sivanadh Vardhinedi
# Name: Name, Length: 93, dtype: object

# %%
data[["Registration Id","Name"]] # accessing sub df
# Out:
#    Registration Id                         Name
# 0       12A21A0378           Peddakota Saikumar
# 1       18A21A0403              Adapa Nagarjuna
# 2       18A21A0405  Addala Mohan Sree Manikanta
# 3       18A21A0411     Andey Venkata Sai Ganesh
# 4       18A21A0412               Geetha Andraju
# ..             ...                          ...
# 88      19A25B0408                  M Ravi Teja
# 89      19A25B0409       Nalluri  Pavan Chandra
# 90      19A25B0410                 P Sai Naveen
# 91      19A25B0411             Pulaparthi Pavan
# 92      19A25B0412          Sivanadh Vardhinedi
#
# [93 rows x 2 columns]

# %%
# Sorting dataframes
data.sort_index(axis = 0,ascending=False)
# axis = 0 row index sorting
# Out:
#     S.No. Registration Id                         Name  \
# 92     93      19A25B0412          Sivanadh Vardhinedi
# 91     92      19A25B0411             Pulaparthi Pavan
# 90     91      19A25B0410                 P Sai Naveen
# 89     90      19A25B0409       Nalluri  Pavan Chandra
# 88     89      19A25B0408                  M Ravi Teja
# ..    ...             ...                          ...
# 4       5      18A21A0412               Geetha Andraju
# 3       4      18A21A0411     Andey Venkata Sai Ganesh
# 2       3      18A21A0405  Addala Mohan Sree Manikanta
# 1       2      18A21A0403              Adapa Nagarjuna
# 0       1      12A21A0378           Peddakota Saikumar
#
#                               Email   Mobile No
# 92      sivavardhinedi335@gmail.com  9347086889
# 91     pavanpulaparthi939@gmail.com  7893195069
# 90         naveensai88178@gmail.com  9550069937
# 89  pavanchowdarynalluri7@gmail.com  8977542433
# 88     mathalaraviteja033@gmail.com  9603795633
# ...

# %%
data.sort_index(axis = 1,ascending=False)
# axis = 1 column index -wise sorting
# Out:
#     S.No. Registration Id                         Name   Mobile No  \
# 0       1      12A21A0378           Peddakota Saikumar  8142539492
# 1       2      18A21A0403              Adapa Nagarjuna  8897693199
# 2       3      18A21A0405  Addala Mohan Sree Manikanta  9704131588
# 3       4      18A21A0411     Andey Venkata Sai Ganesh  7730037728
# 4       5      18A21A0412               Geetha Andraju  9346857667
# ..    ...             ...                          ...         ...
# 88     89      19A25B0408                  M Ravi Teja  9603795633
# 89     90      19A25B0409       Nalluri  Pavan Chandra  8977542433
# 90     91      19A25B0410                 P Sai Naveen  9550069937
# 91     92      19A25B0411             Pulaparthi Pavan  7893195069
# 92     93      19A25B0412          Sivanadh Vardhinedi  9347086889
#
#                               Email
# 0           sai.peddakota@gmail.com
# 1       nagarjunaadapa333@gmail.com
# 2      manikantaaddala970@gmail.com
# ...

# %%
data.sort_values(by = "Name")
# Out:
#     S.No. Registration Id                             Name  \
# 74     75      19A25A0402                   A.G.L.Prasanna
# 1       2      18A21A0403                  Adapa Nagarjuna
# 2       3      18A21A0405      Addala Mohan Sree Manikanta
# 3       4      18A21A0411         Andey Venkata Sai Ganesh
# 82     83      19A25B0401  Atyam Sethu Vardhan Sri Krishna
# ..    ...             ...                              ...
# 35     36      18A21A04A5    Vidya Prameela Podagatlapalli
# 26     27      18A21A0486                  Y.Lakshmi Durga
# 16     17      18A21A0452         Yarramsetty Rama Krishna
# 54     55      18A21A04E7                 Yatham Raveendra
# 55     56      18A21A04E9                Yenumula Sridurga
#
#                              Email   Mobile No
# 74         gayatriankani@gmail.com  9542318364
# 1      nagarjunaadapa333@gmail.com  8897693199
# 2     manikantaaddala970@gmail.com  9704131588
# 3     andeysaiganesh1141@gmail.com  7730037728
# ...

# %%
data.sort_values(by = ["Name","Mobile No"], ascending=False)
# Out:
#     S.No. Registration Id                             Name  \
# 55     56      18A21A04E9                Yenumula Sridurga
# 54     55      18A21A04E7                 Yatham Raveendra
# 16     17      18A21A0452         Yarramsetty Rama Krishna
# 26     27      18A21A0486                  Y.Lakshmi Durga
# 35     36      18A21A04A5    Vidya Prameela Podagatlapalli
# ..    ...             ...                              ...
# 82     83      19A25B0401  Atyam Sethu Vardhan Sri Krishna
# 3       4      18A21A0411         Andey Venkata Sai Ganesh
# 2       3      18A21A0405      Addala Mohan Sree Manikanta
# 1       2      18A21A0403                  Adapa Nagarjuna
# 74     75      19A25A0402                   A.G.L.Prasanna
#
#                              Email   Mobile No
# 55         sinduyenumula@gmail.com  7660098459
# 54   raveendrayatham1234@gmail.com  9133261242
# 16      ramakrishna9182y@gmail.com  9182474494
# 26  lakshmiyelisetti2001@gmail.com  9391200969
# ...

# %%
# Indexing
# Iloc & Loc
data["Name"][77]
# Out:
# 'Jonnalagadda Sai Pavan Kumar'

# %%
data[88:89] # data 2_D
# Out:
#     S.No. Registration Id         Name                         Email  \
# 88     89      19A25B0408  M Ravi Teja  mathalaraviteja033@gmail.com
#
#      Mobile No
# 88  9603795633

# %%
data[1:93:10]
# Out:
#     S.No. Registration Id                                    Name  \
# 1       2      18A21A0403                         Adapa Nagarjuna
# 11     12      18A21A0438                           Sandhya Didde
# 21     22      18A21A0474                       Kotla Pavan Kumar
# 31     32      18A21A0499                Peddada Lakshmi Pranathi
# 41     42      18A21A04B4                          R Purna Sasank
# 51     52      18A21A04D8  L N Veera Venkata Sayeesh Sudabhathula
# 61     62      18A21B0416                                 M.Navya
# 71     72      18A21BO403           Bodapati Naga Venkata Vignesh
# 81     82      19A25B0337                        Ravi Kiran Kumar
# 91     92      19A25B0411                        Pulaparthi Pavan
#
#                             Email   Mobile No
# 1     nagarjunaadapa333@gmail.com  8897693199
# 11      diddesandhya123@gmail.com  9542252369
# 21  kotlapavankumar1999@gmail.com  9182573372
# 31      pranathipeddada@gmail.com  8247754144
# ...

# %%
data.iloc[88] # integer indexing  # i location
# Out:
# S.No.                                        89
# Registration Id                      19A25B0408
# Name                                M Ravi Teja
# Email              mathalaraviteja033@gmail.com
# Mobile No                            9603795633
# Name: 88, dtype: object

# %%
data.iloc[91:]
# Out:
#     S.No. Registration Id                 Name                         Email  \
# 91     92      19A25B0411     Pulaparthi Pavan  pavanpulaparthi939@gmail.com
# 92     93      19A25B0412  Sivanadh Vardhinedi   sivavardhinedi335@gmail.com
#
#      Mobile No
# 91  7893195069
# 92  9347086889

# %%
data.loc[33,"Name"] # Loc - integer and object indexing, column indexing
# Out:
# 'Penke Veera Hanuman Surya Srinath'

# %%
data.loc[[90,89,67],["Name","Email"]] # loc & iloc are attributes in DF
# Out:
#                       Name                            Email
# 90            P Sai Naveen         naveensai88178@gmail.com
# 89  Nalluri  Pavan Chandra  pavanchowdarynalluri7@gmail.com
# 67   Siddineni Guru Charan          siddineni2000@gmail.com

# %% [markdown]
# ### Filtering

# %%
# 9347086889
data[data["Mobile No"] == 9347086889]
# Out:
#     S.No. Registration Id                 Name                        Email  \
# 92     93      19A25B0412  Sivanadh Vardhinedi  sivavardhinedi335@gmail.com
#
#      Mobile No
# 92  9347086889

# %%
data[data["Registration Id"] == "19A25B0412"]
# Out:
#     S.No. Registration Id                 Name                        Email  \
# 92     93      19A25B0412  Sivanadh Vardhinedi  sivavardhinedi335@gmail.com
#
#      Mobile No
# 92  9347086889

# %%
# reading birds dataset
birds = pd.read_csv("birds.csv")
birds
# features of birds 
# 6 birds details
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
birds.columns
# Out:
# Index(['id', 'huml', 'humw', 'ulnal', 'ulnaw', 'feml', 'femw', 'tibl', 'tibw',
#        'tarl', 'tarw', 'type'],
#       dtype='object')

# %%
birds.shape
# Out:
# (420, 12)

# %%
birds["type"].value_counts() # unique data with count
# Out:
# SO    128
# SW    116
# W      65
# R      50
# P      38
# T      23
# Name: type, dtype: int64

# %%
birds[birds["type"] == "T"]
# Out:
#       id    huml   humw   ulnal  ulnaw    feml   femw    tibl   tibw    tarl  \
# 181  181   43.97   4.64   51.07   3.80   38.76   3.18   55.67   2.88   30.41
# 182  182   44.58   5.76   52.76   4.84   40.47   3.76   56.42   3.31   31.32
# 183  183   20.25   2.35   25.14   1.76   20.17   1.37   27.67   1.41   15.68
# 184  184   48.70   5.46   57.39   3.73   42.56   3.07   52.42   2.85   27.23
# 185  185   35.74   3.91   39.20   2.93   33.01   2.65   42.80   2.18   24.85
# 186  186   37.69   4.18   43.30   3.38   35.00   2.87   49.15   2.37   26.33
# 187  187   31.26   3.60   35.24   2.91   28.62   2.42   39.04   2.32   21.88
# 188  188   30.97   3.65   36.47   2.96   28.03   2.21   37.41   1.99   21.11
# 189  189   30.31   3.36   34.83   2.49   26.36   2.17   34.16   1.88   18.72
# 190  190   32.02   2.99   27.70   2.38   38.27   2.64   53.33   2.71   31.00
# 191  191   32.34   3.17   29.05   2.36   39.64   2.70   55.36   2.51   37.08
# ...

# %% [markdown]
# ### Grouping

# %%
g_data = birds.groupby("type")
g_data

# %%
for name,group in g_data:
    print(name, group)
# Out:
# P       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 254  254  29.26  2.66  27.63   2.23  27.87  2.03  38.90  1.81  25.22  1.62
# 255  255  30.60  2.45  25.90   1.87  32.36  2.10  50.25  1.88  33.58  1.88
# 256  256  30.25  2.29  25.14   1.87  31.61  2.18  50.98  2.00  33.50  1.93
# 257  257  42.52  2.99  36.73   2.91  52.24  3.81  81.57  3.71  61.27  2.71
# 258  258  45.60  3.35  38.73   3.52  54.45  4.10  83.59  3.72  63.91  2.67
# 259  259  43.97  3.54  38.38   3.14  52.49  4.25  83.15  4.12  61.08  3.04
# 260  260  46.38  3.41  39.80   3.48  54.67  4.08  85.88  4.04  63.75  3.09
# 261  261  45.57  4.64  57.13   2.93  28.32  2.26  36.95  1.96  19.75  2.16
# 262  262  33.81  2.80  42.82   2.22  18.88  1.45  26.28  1.31  14.45  1.29
# 263  263  31.72  2.64  40.00   1.99  20.36  1.59  32.21  1.62  17.72  1.52
# 264  264   9.85  2.88  14.73   1.73  16.27  1.22  20.89  1.25   7.77  1.23
# ...

# %%
g_data.first()
# Out:
#        id    huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw    tarl  \
# type
# P     254   29.26  2.66   27.63   2.23  27.87  2.03   38.90  1.81   25.22
# R     204   63.76  4.74   69.06   4.08  57.33  4.88   75.67  4.33   60.19
# SO    292   29.61  2.41   33.93   2.02  30.79  2.19   51.64  2.01   37.33
# SW      0   80.78  6.68   72.01   4.88  41.81  3.70    5.50  4.03   38.70
# T     181   43.97  4.64   51.07   3.80  38.76  3.18   55.67  2.88   30.41
# W     116  157.00  9.00  192.00   7.02  85.60  6.44  227.00  6.84  175.00
#
#       tarw
# type
# P     1.62
# R     3.82
# SO    1.78
# SW    3.84
# T     2.83
# W     6.77

# %%
g_data.last()
# Out:
#        id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# P     291  41.60  3.74  56.50   3.02  37.00  2.99  62.90  2.82  38.21  2.51
# R     253  35.63  2.40  42.67   2.02  28.51  2.41  42.64  2.46  21.05  3.12
# SO    419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
# SW    115  98.73  6.48  91.69   5.31  35.34  4.02  92.36  4.46  50.53  2.69
# T     203  39.64  4.07  37.32   2.98  45.50  3.42  64.45  3.37  37.77  2.86
# W     180  87.01  5.18  94.34   4.45  35.73  2.80  67.12  2.93  43.43  2.34

# %% [markdown]
# ### Statistical

# %%
birds["huml"].mean()
# Out:
# 64.6505011933174

# %%
birds["huml"].min()
# Out:
# 9.85

# %%
birds["huml"].max()
# Out:
# 420.0

# %%
birds["huml"].describe()
# Out:
# count    419.000000
# mean      64.650501
# std       53.834549
# min        9.850000
# 25%       25.170000
# 50%       44.180000
# 75%       90.310000
# max      420.000000
# Name: huml, dtype: float64

# %%
df2.isnull()
# Out:
#     Name  Branch    DOB
# 1  False   False  False
# 2  False   False   True
# 3  False    True  False
# 4  False   False  False

# %%
birds - 420
6 birds - 420
r,t,p,so,sw,s

grouping -  P - 23

# %%
# saving - exporting
df2.to_excel("data.xlsx")
df2.to_csv("sample.csv")

# %% [markdown]
# ## Matplotlib
# #### Visualization with Python
# * can analyze the data with form of pictures
# * Repepresenting the data in the form of diagrams
# * Easy to Understand
# * Set of information as a chart or other image
# * pip install matplotlib
#
#     * Line Plot
#     * Scatter Plot
#     * Bar Graph
#     * Pie Chart

# %%
import matplotlib.pyplot as plt

# %%
# Line Plot
import numpy as np
x = np.arange(20)
y = x**2
plt.plot(x,y)
plt.show()

# %%
x = np.arange(20)
y = x**2
plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Sample Line Plot")
plt.plot(x,y)
plt.show()

# %%
x = np.arange(20)
y = x**2
plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Sample Line Plot")
plt.plot(x,x**2, label = "Squares", linestyle = ":")
plt.plot(x,x**3, label = "cubes", linestyle = "-.")
plt.plot(x,x**4, label = "X**4", linestyle = "-.")
plt.legend( loc = "center")
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
x = np.linspace(1,100,4)
y = np.random.randint(1,100,4)
print(x)
print(y)
plt.scatter(x,y, color = ["r","y","b","black"])
plt.show()
# finding the probability
# Out:
# [  1.  34.  67. 100.]
# [97 89 79 99]

# %% [markdown]
# # Bar Graph

# %%
x = [90,89,67,98]
y = ["2-1","2-2","3-1","3-2"]
plt.bar(y,x)
plt.show()
# gives us relations between 2 groups

# %% [markdown]
# # Pie Chart

# %%
# 360
x = [90,8,78,76,78]
plt.pie(x,labels = ["C","Python","Java","C++","R"], colors =["r","black","white","green","y"])
plt.xlim(10,10)
# plt.ylim(5,5)
plt.show()
# 100%, 360 degree
# Out:
# <ipython-input-108-7414a232c815>:4: UserWarning: Attempting to set identical left == right == 10 results in singular transformations; automatically expanding.
#   plt.xlim(10,10)

# %% [markdown]
# ## OOP - Python
# * What is Object Oriented Programming?
#
#  *   To solve programming problem is by Creating Objects. This is known as OOPS
#     Object Oriented Programming (OOP) allows decomposition of a problem into a number of units called objects
#  *   Python, an Object Oriented programming (OOP), is a way of programming that focuses on using objects and classes to design and build applications.
#
# * **Why to Choose ObjectOriented Programming?**
#
# * Python was designed with an object-oriented approach.
#
# * OOP offers the following advantages:
#          - Provides a clear program structure, which makes it easy to map real world problems                and their solutions.
#          -  Facilitates easy maintenance and
#          -  modification of existing code.
#          *  Imparts code reusability
#
# * ***object***
#
#   *  An object is physical entity
#   *  An object is an instance of a class. When class is defined, only the description for the object is defined. Therefore, no memory or storage is allocated.
#   * Every Object contrains 2 Characteristics
#       * State/Properties/Attributes
#       * Behaviour
#
#
# * ***class***
#
#   *  Combination of both attributes and methods
#   *  A class is a way to take a grouping of functions and data and place them inside a container
#     Ex: Building and Templates
#
# * NOTE : Class attributes(variables) belong to the class itself they will be shared by all the instances.
#
# *  Attributes are variables of a class that are shared between all of its instances
#
#
# ### method
#
#  * A name given to a function which is defined inside a class.They are used to define the behaviors of an object

# %% [markdown]
#  ```python
# # Syntax for Class
# class ClassName:
#     pass
# ClassName()```

# %%
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
f = "lavanya"
print(type(f))
# Out:
# <class 'str'>

# %%
class myClass:
    a = "Lavanya" # a is attribute
    def add():
        print("hii")
    
# myClass.a
# # myClass.add(90,90)
# ob = myClass()
# ob.a
print(ob.add) # object.Method
myClass.add()# class.Method()
# Out:
# <bound method myClass.add of <__main__.myClass object at 0x000001E5E2F7A700>>
# hii

# %%
myClass.add
# Out:
# <function __main__.myClass.add(self, a, b)>

# %%
def add():
        a = 10
        b = 19
        return a+b
    
add()
# Out:
# 29

# %%
# creating object
obj = myClass()
obj

# %%
obj.a
# Out:
# 'Lavanya'

# %%
class phone:
    def __init__(self): # constructor
        print("hii.. hello")
    def mob():
        print("32gb, 512 sd, 1Tb")

        
phone.mob() # classname.method
# Out:
# 32gb, 512 sd, 1Tb

# %%
ob = phone()
# Out:
# hii.. hello

# %%
ob.mob()  # object.method
# Out:
# 32gb, 512 sd, 1Tb

# %%
github  - python 
course - SCM git & github / github
